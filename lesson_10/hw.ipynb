# %% [markdown]
# # Домашнее задание
#
# ## LoRA w/ SDXL
#
# В этом задании вы воспроизведете обучение lora, которое мы проходили на семинаре. Отличием от семинарского занятия будет тот факт, что вам будет необходимо обучить lora для SDXL, а не SD1.5
#
# Для успешного выполнения (получения максимального балла) необходимо:
# - Выбрать датасет (вы можете взять тот же самый датасет из семинара, но можете попробовать что-то другое)
# - Обучаем только Unet, `TRAIN_TEXT_ENCODER = False`
# - Сделать правильную функцию кеширования (она будет отличаться от функции на семинаре)
# - Сделать возможность обучения с `batch_size > 1`
# - Обучить только base u-net (то есть первую модель каскада)
# - Сделать inference finetuned модели (запустить только base u-net)
# - Сделать inference finetuned модели (запустить base + refine) – на коллабе может не хватить места, следите за потреблением памяти
# - Сравните результаты: base и base+refined. Что получилось, по вашему мнению, лучше? Почему? (*Note* для выводов 1го примера будет недостаточно, сгенирируйте хотя бы по 8 картинок)

# %%
# ваш код

# %% [markdown]
# p.s.
#
# Если вам интересно, советуем почитать про [textual inversion](https://huggingface.co/docs/diffusers/training/text_inversion) как еще один peft метод (более эффективный в плане памяти, но чуть хуже по качеству)
